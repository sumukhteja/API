# %%
text = 'The quick brown fox jumps over the lazy dog.'  # The text you want to check the score

# %%
import requests
import hashlib
import time

api_key = 'THISISATESTKEYTHEREAREMANYLIKEIT'  # Replace with your actual API key
api_url = 'https://api.readable.com/api/text/'
request_time = str(int(time.time()))  # Time of request in Unix timestamp format
api_signature = hashlib.md5((api_key + request_time).encode()).hexdigest()  # Generate signature

headers = {
    'API_SIGNATURE': api_signature,
    'API_REQUEST_TIME': request_time
}

payload = {
    'text': text
}

response = requests.post(api_url, headers=headers, data=payload)
data = response.json()

# Fetch the required fields from the response data
paragraph_count = data['paragraph_count']
sentence_count = data['sentence_count']
sentence_count_flesch = data['sentence_count_flesch']
letter_count = data['letter_count']
word_count = data['word_count']
lensear_word_count = data['lensear_word_count']
syllable_count = data['syllable_count']
unique_word_count = data['unique_word_count']
word_with_three_syllables = data['word_with_three_syllables']
word_with_three_syllables_common_only = data['word_with_three_syllables_common_only']
dale_chall_difficult_words = data['dale_chall_difficult_words']
spache_difficult_words = data['spache_difficult_words']
cefr_level = data['cefr_level']
ielts_level = data['ielts_level']
composition_adjective_count = data['composition_adjective_count']
composition_adverb_count = data['composition_adverb_count']
composition_conjunction_count = data['composition_conjunction_count']
composition_determiner_count = data['composition_determiner_count']
composition_interjection_count = data['composition_interjection_count']
composition_noun_count = data['composition_noun_count']
composition_preposition_count = data['composition_preposition_count']
composition_pronoun_count = data['composition_pronoun_count']
composition_proper_noun_count = data['composition_proper_noun_count']
composition_qualifier_count = data['composition_qualifier_count']
composition_verb_count = data['composition_verb_count']
composition_unknown_count = data['composition_unknown_count']
composition_nonword_count = data['composition_nonword_count']
flesch_reading_ease = data['flesch_reading_ease']
flesch_kincaid_grade_level = data['flesch_kincaid_grade_level']
gunning_fog_score = data['gunning_fog_score']
powers_sumner_kearl_score = data['powers_sumner_kearl_score']
coleman_liau_index = data['coleman_liau_index']
automated_readability_index = data['automated_readability_index']
smog_index = data['smog_index']
dale_chall_readability_score = data['dale_chall_readability_score']
spache_readability_score = data['spache_readability_score']
forcast_grade = data['forcast_grade']
lix_score = data['lix_score']
rix_score = data['rix_score']
lensear_write = data['lensear_write']
raygor_grade = data['raygor_grade']
fry_grade = data['fry_grade']
longest_word_syllables = data['longest_word_syllables']
longest_word_letters = data['longest_word_letters']
longest_sentence_words = data['longest_sentence_words']
tone_number = data['tone_number']
sentiment = data['sentiment']
sentiment_number = data['sentiment_number']
personal_number = data['personal_number']
gender_number = data['gender_number']
rating = data['rating']
sentences_per_paragraph = data['sentences_per_paragraph']
words_per_paragraph = data['words_per_paragraph']
words_per_sentence = data['words_per_sentence']
words_per_sentence_flesch = data['words_per_sentence_flesch']
syllables_per_word = data['syllables_per_word']
letters_per_word = data['letters_per_word']
average_grade_level = data['average_grade_level']
reading_time = data['reading_time']
speaking_time = data['speaking_time']
gender = data['gender']
tone = data['tone']
personal = data['personal']
keyword_density = data['keyword_density']
reach = data['reach']
reach_public = data['reach_public']
flesch_kincaid_reading_ease = data['flesch_kincaid_reading_ease']
score_id = data['score_id']
server_reference = data['server_reference']
result = data['result']
response_timestamp = data['response_timestamp']

# Create a dictionary of the fetched fields
score_data = {
    'paragraph_count': paragraph_count,
    'sentence_count': sentence_count,
    'sentence_count_flesch': sentence_count_flesch,
    'letter_count': letter_count,
    'word_count': word_count,
    'lensear_word_count': lensear_word_count,
    'syllable_count': syllable_count,
    'unique_word_count': unique_word_count,
    'word_with_three_syllables': word_with_three_syllables,
    'word_with_three_syllables_common_only': word_with_three_syllables_common_only,
    'dale_chall_difficult_words': dale_chall_difficult_words,
    'spache_difficult_words': spache_difficult_words,
    'cefr_level': cefr_level,
    'ielts_level': ielts_level,
    'composition_adjective_count': composition_adjective_count,
    'composition_adverb_count': composition_adverb_count,
    'composition_conjunction_count': composition_conjunction_count,
    'composition_determiner_count': composition_determiner_count,
    'composition_interjection_count': composition_interjection_count,
    'composition_noun_count': composition_noun_count,
    'composition_preposition_count': composition_preposition_count,
    'composition_pronoun_count': composition_pronoun_count,
    'composition_proper_noun_count': composition_proper_noun_count,
    'composition_qualifier_count': composition_qualifier_count,
    'composition_verb_count': composition_verb_count,
    'composition_unknown_count': composition_unknown_count,
    'composition_nonword_count': composition_nonword_count,
    'flesch_reading_ease': flesch_reading_ease,
    'flesch_kincaid_grade_level': flesch_kincaid_grade_level,
    'gunning_fog_score': gunning_fog_score,
    'powers_sumner_kearl_score': powers_sumner_kearl_score,
    'coleman_liau_index': coleman_liau_index,
    'automated_readability_index': automated_readability_index,
    'smog_index': smog_index,
    'dale_chall_readability_score': dale_chall_readability_score,
    'spache_readability_score': spache_readability_score,
    'forcast_grade': forcast_grade,
        'lix_score': lix_score,
    'rix_score': rix_score,
    'lensear_write': lensear_write,
    'raygor_grade': raygor_grade,
    'fry_grade': fry_grade,
    'longest_word_syllables': longest_word_syllables,
    'longest_word_letters': longest_word_letters,
    'longest_sentence_words': longest_sentence_words,
    'tone_number': tone_number,
    'sentiment': sentiment,
    'sentiment_number': sentiment_number,
    'personal_number': personal_number,
    'gender_number': gender_number,
    'rating': rating,
    'sentences_per_paragraph': sentences_per_paragraph,
    'words_per_paragraph': words_per_paragraph,
    'words_per_sentence': words_per_sentence,
    'words_per_sentence_flesch': words_per_sentence_flesch,
    'syllables_per_word': syllables_per_word,
    'letters_per_word': letters_per_word,
    'average_grade_level': average_grade_level,
    'reading_time': reading_time,
    'speaking_time': speaking_time,
    'gender': gender,
    'tone': tone,
    'personal': personal,
    'keyword_density': keyword_density,
    'reach': reach,
    'reach_public': reach_public,
    'flesch_kincaid_reading_ease': flesch_kincaid_reading_ease,
    'score_id': score_id,
    'server_reference': server_reference,
    'result': result,
    'response_timestamp': response_timestamp
}

# Print the fetched fields
for field, value in score_data.items():
    print(f'{field}: {value}')
# Out:
# paragraph_count: 1
# sentence_count: 8
# sentence_count_flesch: 11
# letter_count: 884
# word_count: 201
# lensear_word_count: 122
# syllable_count: 301
# unique_word_count: 134
# word_with_three_syllables: 22
# word_with_three_syllables_common_only: 20
# dale_chall_difficult_words: 38
# spache_difficult_words: 51
# cefr_level: C2
# ielts_level: 8+
# composition_adjective_count: 15
# composition_adverb_count: 11
# composition_conjunction_count: 17
# composition_determiner_count: 30
# composition_interjection_count: 1
# composition_noun_count: 48
# composition_preposition_count: 25
# composition_pronoun_count: 32
# composition_proper_noun_count: 3
# composition_qualifier_count: 5
# composition_verb_count: 18
# composition_unknown_count: 0
# composition_nonword_count: 0
# flesch_reading_ease: 61.6
# flesch_kincaid_grade_level: 9.2
# gunning_fog_score: 11.3
# powers_sumner_kearl_score: 6.3
# coleman_liau_index: 8.9
# automated_readability_index: 11.8
# smog_index: 12.6
# ...
